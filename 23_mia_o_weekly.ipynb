# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('C:/Users/ps3ma/New folder/miami/play_by_play_2023.csv')
# Out:
# C:\Users\ps3ma\AppData\Local\Temp\ipykernel_39488\1673019333.py:1: DtypeWarning: Columns (179,180,182,183,205,206,213,214,218,219,220,253,254,255,260,262,263,266,267,268,269,283,284,332) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/ps3ma/New folder/miami/play_by_play_2023.csv')

# %%
df = df[(df['week'] == 4) & (df['posteam'] == 'MIA')]

# %%
df['play_type'].value_counts()
# Out:
# pass           40
# run            19
# kickoff         9
# no_play         8
# punt            3
# extra_point     2
# Name: play_type, dtype: int64

# %%
df = df[(df['play_type'] != 'no_play') & (df['play_type'] != 'kickoff') & (df['play_type'] != 'punt') &(df['play_type'] != 'extra_point')  ]

# %%
df['play_type'].value_counts()
# Out:
# pass    40
# run     19
# Name: play_type, dtype: int64

# %%
df
# Out:
#        play_id          game_id  old_game_id home_team away_team season_type  \
# 10081      302  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10082      327  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10083      352  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10084      374  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10085      403  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10087      467  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10088      492  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10105      892  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10106      932  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10107      954  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# 10108      974  2023_04_MIA_BUF   2023100101       BUF       MIA         REG
# ...

# %%
run_yards = df[df['play_type'] == 'run']
run_yards['yards_gained'].value_counts()
# Out:
#  3.0     4
#  4.0     3
# -2.0     2
#  2.0     1
#  1.0     1
#  10.0    1
#  15.0    1
#  14.0    1
#  0.0     1
#  6.0     1
#  55.0    1
#  8.0     1
#  11.0    1
# Name: yards_gained, dtype: int64

# %%
run_yards = run_yards['yards_gained'].sum()
run_yards
# Out:
# 142.0

# %%
run_yards/19
# Out:
# 7.473684210526316

# %%
# ypc with outlier removed
(142 - 55)/18
# Out:
# 4.833333333333333

# %%
pass_yards = df[df['play_type'] == 'pass']
pass_yards['yards_gained'].value_counts()
# Out:
#  0.0     11
#  7.0      4
#  5.0      3
#  17.0     2
#  11.0     2
#  19.0     2
#  22.0     2
# -8.0      2
#  4.0      1
#  1.0      1
#  23.0     1
# -11.0     1
#  8.0      1
# -4.0      1
#  9.0      1
#  3.0      1
#  15.0     1
#  2.0      1
#  20.0     1
#  16.0     1
# Name: yards_gained, dtype: int64

# %%
pass_yards = pass_yards['yards_gained'].sum()
pass_yards
# Out:
# 251.0

# %%
251/40
# Out:
# 6.275

# %%
# yards lost from sacks
8+8+11+4
# Out:
# 31

# %%
sg_yards = df[df['shotgun'] == 1]
sg_yards['yards_gained'].value_counts()
# Out:
#  0.0     10
#  7.0      4
#  3.0      4
#  4.0      4
#  5.0      3
#  8.0      2
# -8.0      2
#  2.0      2
#  11.0     2
#  22.0     2
# -2.0      2
#  17.0     2
#  1.0      1
#  23.0     1
# -11.0     1
#  55.0     1
#  9.0      1
#  6.0      1
# -4.0      1
#  15.0     1
#  20.0     1
#  19.0     1
#  16.0     1
# Name: yards_gained, dtype: int64

# %%
sg_yards = sg_yards['yards_gained'].sum()
sg_yards
# Out:
# 320.0

# %%
# shotgun y/p
320/50
# Out:
# 6.4

# %%
sb_yards = df[df['shotgun'] == 0]
sb_yards['yards_gained'].value_counts()
# Out:
# 0.0     2
# 1.0     1
# 10.0    1
# 3.0     1
# 15.0    1
# 14.0    1
# 19.0    1
# 11.0    1
# Name: yards_gained, dtype: int64

# %%
sb_yards = sb_yards['yards_gained'].sum()
sb_yards
# Out:
# 73.0

# %%
# singleback y/p
73/8
# Out:
# 9.125

# %%
pass_ = (df[df['pass_length'] != 'NaN'])
pass_['pass_length'].value_counts()
# Out:
# short    30
# deep      5
# Name: pass_length, dtype: int64

# %%
pass_len = pass_.groupby(['pass_length']).sum()
pass_len['yards_gained']
# Out:
# C:\Users\ps3ma\AppData\Local\Temp\ipykernel_39488\1098610778.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pass_len = pass_.groupby(['pass_length']).sum()
# pass_length
# deep      84.0
# short    198.0
# Name: yards_gained, dtype: float64

# %%
print(f' Short y/a: {198/30}')

print(f' Deep y/a: {84/5}')
# Out:
#  Short y/a: 6.6
#  Deep y/a: 16.8

# %%
pass_['pass_location'].value_counts()
# Out:
# left      24
# right      7
# middle     4
# Name: pass_location, dtype: int64

# %%
pass_loc = pass_.groupby(['pass_location']).sum()
pass_loc['yards_gained']
# Out:
# C:\Users\ps3ma\AppData\Local\Temp\ipykernel_39488\3641998645.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pass_loc = pass_.groupby(['pass_location']).sum()
# pass_location
# left      163.0
# middle     42.0
# right      77.0
# Name: yards_gained, dtype: float64

# %%
print(f' left y/a: {163/24}')

print(f' middle y/a: {52/7}')

print(f' right y/a: {77/4}')
# Out:
#  left y/a: 6.791666666666667
#  middle y/a: 7.428571428571429
#  right y/a: 19.25

# %%
run_ = (df[df['run_location'] != 'NaN'])
run_['run_location'].value_counts()
# Out:
# right     8
# left      7
# middle    4
# Name: run_location, dtype: int64

# %%
run_loc = run_.groupby(['run_location']).sum()
run_loc['yards_gained']
# Out:
# C:\Users\ps3ma\AppData\Local\Temp\ipykernel_39488\1393010925.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   run_loc = run_.groupby(['run_location']).sum()
# run_location
# left      56.0
# middle     8.0
# right     78.0
# Name: yards_gained, dtype: float64

# %%
print(f' left y/a: {56/7}')

print(f' middle y/a: {8/4}')

print(f' right y/a: {78/8}')
# Out:
#  left y/a: 8.0
#  middle y/a: 2.0
#  right y/a: 9.75

# %%
run_['run_gap'].value_counts()
# Out:
# end       10
# guard      3
# tackle     2
# Name: run_gap, dtype: int64

# %%
run_gap = run_.groupby(['run_gap']).sum()
run_gap['yards_gained']
# Out:
# C:\Users\ps3ma\AppData\Local\Temp\ipykernel_39488\595829846.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   run_gap = run_.groupby(['run_gap']).sum()
# run_gap
# end       115.0
# guard      17.0
# tackle      2.0
# Name: yards_gained, dtype: float64

# %%
print(f' end y/a: {115/10}')

print(f' guard y/a: {17/3}')

print(f' tackle y/a: {2/2}')
# Out:
#  end y/a: 11.5
#  guard y/a: 5.666666666666667
#  tackle y/a: 1.0
